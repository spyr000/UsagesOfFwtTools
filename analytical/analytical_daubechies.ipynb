# %% [markdown]
# # Преобразование сигнала при помощи коэффициентов Добеши

# %%
# !pip install fwt-tools
# Out:
# Requirement already satisfied: fwt-tools in c:\users\sam\miniconda3\lib\site-packages (1.0.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\sam\miniconda3\lib\site-packages (from fwt-tools) (2.2.6)
# Requirement already satisfied: numba>=0.60.0 in c:\users\sam\miniconda3\lib\site-packages (from fwt-tools) (0.61.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\sam\miniconda3\lib\site-packages (from numba>=0.60.0->fwt-tools) (0.44.0)

# %%
import time

import matplotlib.pyplot as plt
from fwttools.fwt_tools import FwtTools
from fwttools.utils.daubechies_coefficients import *
from fwttools.utils.error import *

from common import signal

# %% [markdown]
# ## D2

# %%
start_time = time.time()

h = daubechies_h_coeffs[2]
kmin, kmax = 0, len(h) - 1

fwttools = FwtTools(h_coeffs=h, kmin=kmin, kmax=kmax)
transform = fwttools.fwt(signal=signal)
synthesized = fwttools.ifwt(wavelet_coefficients=transform)

end_time = time.time()
execution_time = end_time - start_time

left, right = parseval_identity(signal, transform)
error = relative_rmse_error(signal, synthesized) * 100

print(f"Равенство Парсеваля: {left} = {right}")
print(f"Время выполнения: {execution_time:.6f} секунд")

fig, ax = plt.subplots(figsize=(12, 6))
line1, = ax.plot(synthesized, label='Аппроксимация', color='green', linestyle='dashed', linewidth=4, marker='8')
line2, = ax.plot(signal, label='Аудиосигнал', color='black', linewidth=0, marker='o')
dummy_line = plt.Line2D([], [], color='none', label=rf'$\epsilon={error:.1f}\%$')


ax.grid(True, which="major", linestyle="-", linewidth=0.8)
ax.minorticks_on()
ax.grid(True, which="minor", linestyle=":", linewidth=0.5)

ax.legend(handles=[line1, line2, dummy_line], labelcolor="black", prop={'size': 25}, loc='upper left')
plt.title(f'Аппроксимация сигнала', fontsize=25)
plt.show()
# Out:
# Равенство Парсеваля: 4791000.0 = 4790999.999999995
# Время выполнения: 0.000000 секунд

# %% [markdown]
# ## D3

# %%
start_time = time.time()

h = daubechies_h_coeffs[3]
kmin, kmax = 0, len(h) - 1

fwttools = FwtTools(h_coeffs=h, kmin=kmin, kmax=kmax)
transform = fwttools.fwt(signal=signal)
synthesized = fwttools.ifwt(wavelet_coefficients=transform)

end_time = time.time()
execution_time = end_time - start_time

left, right = parseval_identity(signal, transform)
error = relative_rmse_error(signal, synthesized) * 100

print(f"Равенство Парсеваля: {left} = {right}")
print(f"Время выполнения: {execution_time:.6f} секунд")

fig, ax = plt.subplots(figsize=(12, 6))
line1, = ax.plot(synthesized, label='Аппроксимация', color='green', linestyle='dashed', linewidth=4, marker='8')
line2, = ax.plot(signal, label='Аудиосигнал', color='black', linewidth=0, marker='o')
dummy_line = plt.Line2D([], [], color='none', label=rf'$\epsilon={error:.1f}\%$')


ax.grid(True, which="major", linestyle="-", linewidth=0.8)
ax.minorticks_on()
ax.grid(True, which="minor", linestyle=":", linewidth=0.5)

ax.legend(handles=[line1, line2, dummy_line], labelcolor="black", prop={'size': 25}, loc='upper left')
plt.title(f'Аппроксимация сигнала', fontsize=25)
plt.show()
# Out:
# Равенство Парсеваля: 4791000.0 = 4790999.999999982
# Время выполнения: 0.000000 секунд

# %% [markdown]
# ## D4

# %%
start_time = time.time()

h = daubechies_h_coeffs[4]
kmin, kmax = 0, len(h) - 1

fwttools = FwtTools(h_coeffs=h, kmin=kmin, kmax=kmax)
transform = fwttools.fwt(signal=signal)
synthesized = fwttools.ifwt(wavelet_coefficients=transform)

end_time = time.time()
execution_time = end_time - start_time

left, right = parseval_identity(signal, transform)
error = relative_rmse_error(signal, synthesized) * 100

print(f"Равенство Парсеваля: {left} = {right}")
print(f"Время выполнения: {execution_time:.6f} секунд")

fig, ax = plt.subplots(figsize=(12, 6))
line1, = ax.plot(synthesized, label='Аппроксимация', color='green', linestyle='dashed', linewidth=4, marker='8')
line2, = ax.plot(signal, label='Аудиосигнал', color='black', linewidth=0, marker='o')
dummy_line = plt.Line2D([], [], color='none', label=rf'$\epsilon={error:.1f}\%$')


ax.grid(True, which="major", linestyle="-", linewidth=0.8)
ax.minorticks_on()
ax.grid(True, which="minor", linestyle=":", linewidth=0.5)

ax.legend(handles=[line1, line2, dummy_line], labelcolor="black", prop={'size': 25}, loc='upper left')
plt.title(f'Аппроксимация сигнала', fontsize=25)
plt.show()
# Out:
# Равенство Парсеваля: 4791000.0 = 4791000.000338162
# Время выполнения: 0.001001 секунд

# %% [markdown]
# ## D5

# %%
start_time = time.time()

h = daubechies_h_coeffs[5]
kmin, kmax = 0, len(h) - 1

fwttools = FwtTools(h_coeffs=h, kmin=kmin, kmax=kmax)
transform = fwttools.fwt(signal=signal)
synthesized = fwttools.ifwt(wavelet_coefficients=transform)

end_time = time.time()
execution_time = end_time - start_time

left, right = parseval_identity(signal, transform)
error = relative_rmse_error(signal, synthesized) * 100

print(f"Равенство Парсеваля: {left} = {right}")
print(f"Время выполнения: {execution_time:.6f} секунд")

fig, ax = plt.subplots(figsize=(12, 6))
line1, = ax.plot(synthesized, label='Аппроксимация', color='green', linestyle='dashed', linewidth=4, marker='8')
line2, = ax.plot(signal, label='Аудиосигнал', color='black', linewidth=0, marker='o')
dummy_line = plt.Line2D([], [], color='none', label=rf'$\epsilon={error:.1f}\%$')


ax.grid(True, which="major", linestyle="-", linewidth=0.8)
ax.minorticks_on()
ax.grid(True, which="minor", linestyle=":", linewidth=0.5)

ax.legend(handles=[line1, line2, dummy_line], labelcolor="black", prop={'size': 25}, loc='upper left')
plt.title(f'Аппроксимация сигнала', fontsize=25)
plt.show()
# Out:
# Равенство Парсеваля: 4791000.0 = 4790999.999999977
# Время выполнения: 0.000000 секунд

# %% [markdown]
# ## D6

# %%
start_time = time.time()

h = daubechies_h_coeffs[6]
kmin, kmax = 0, len(h) - 1

fwttools = FwtTools(h_coeffs=h, kmin=kmin, kmax=kmax)
transform = fwttools.fwt(signal=signal)
synthesized = fwttools.ifwt(wavelet_coefficients=transform)

end_time = time.time()
execution_time = end_time - start_time

left, right = parseval_identity(signal, transform)
error = relative_rmse_error(signal, synthesized) * 100

print(f"Равенство Парсеваля: {left} = {right}")
print(f"Время выполнения: {execution_time:.6f} секунд")

fig, ax = plt.subplots(figsize=(12, 6))
line1, = ax.plot(synthesized, label='Аппроксимация', color='green', linestyle='dashed', linewidth=4, marker='8')
line2, = ax.plot(signal, label='Аудиосигнал', color='black', linewidth=0, marker='o')
dummy_line = plt.Line2D([], [], color='none', label=rf'$\epsilon={error:.1f}\%$')


ax.grid(True, which="major", linestyle="-", linewidth=0.8)
ax.minorticks_on()
ax.grid(True, which="minor", linestyle=":", linewidth=0.5)

ax.legend(handles=[line1, line2, dummy_line], labelcolor="black", prop={'size': 25}, loc='upper left')
plt.title(f'Аппроксимация сигнала', fontsize=25)
plt.show()
# Out:
# Равенство Парсеваля: 4791000.0 = 4790999.9999999795
# Время выполнения: 0.000000 секунд

# %% [markdown]
# ## D7

# %%
start_time = time.time()

h = daubechies_h_coeffs[7]
kmin, kmax = 0, len(h) - 1

fwttools = FwtTools(h_coeffs=h, kmin=kmin, kmax=kmax)
transform = fwttools.fwt(signal=signal)
synthesized = fwttools.ifwt(wavelet_coefficients=transform)

end_time = time.time()
execution_time = end_time - start_time

left, right = parseval_identity(signal, transform)
error = relative_rmse_error(signal, synthesized) * 100

print(f"Равенство Парсеваля: {left} = {right}")
print(f"Время выполнения: {execution_time:.6f} секунд")

fig, ax = plt.subplots(figsize=(12, 6))
line1, = ax.plot(synthesized, label='Аппроксимация', color='green', linestyle='dashed', linewidth=4, marker='8')
line2, = ax.plot(signal, label='Аудиосигнал', color='black', linewidth=0, marker='o')
dummy_line = plt.Line2D([], [], color='none', label=rf'$\epsilon={error:.1f}\%$')


ax.grid(True, which="major", linestyle="-", linewidth=0.8)
ax.minorticks_on()
ax.grid(True, which="minor", linestyle=":", linewidth=0.5)

ax.legend(handles=[line1, line2, dummy_line], labelcolor="black", prop={'size': 25}, loc='upper left')
plt.title(f'Аппроксимация сигнала', fontsize=25)
plt.show()
# Out:
# Равенство Парсеваля: 4791000.0 = 4790999.997941729
# Время выполнения: 0.001000 секунд

# %% [markdown]
# ## D8

# %%
start_time = time.time()

h = daubechies_h_coeffs[8]
kmin, kmax = 0, len(h) - 1

fwttools = FwtTools(h_coeffs=h, kmin=kmin, kmax=kmax)
transform = fwttools.fwt(signal=signal)
synthesized = fwttools.ifwt(wavelet_coefficients=transform)

end_time = time.time()
execution_time = end_time - start_time

left, right = parseval_identity(signal, transform)
error = relative_rmse_error(signal, synthesized) * 100

print(f"Равенство Парсеваля: {left} = {right}")
print(f"Время выполнения: {execution_time:.6f} секунд")

fig, ax = plt.subplots(figsize=(12, 6))
line1, = ax.plot(synthesized, label='Аппроксимация', color='green', linestyle='dashed', linewidth=4, marker='8')
line2, = ax.plot(signal, label='Аудиосигнал', color='black', linewidth=0, marker='o')
dummy_line = plt.Line2D([], [], color='none', label=rf'$\epsilon={error:.1f}\%$')


ax.grid(True, which="major", linestyle="-", linewidth=0.8)
ax.minorticks_on()
ax.grid(True, which="minor", linestyle=":", linewidth=0.5)

ax.legend(handles=[line1, line2, dummy_line], labelcolor="black", prop={'size': 25}, loc='upper left')
plt.title(f'Аппроксимация сигнала', fontsize=25)
plt.show()
# Out:
# Равенство Парсеваля: 4791000.0 = 4790999.999695626
# Время выполнения: 0.000000 секунд

# %% [markdown]
# ## D9

# %%
start_time = time.time()

h = daubechies_h_coeffs[9]
kmin, kmax = 0, len(h) - 1

fwttools = FwtTools(h_coeffs=h, kmin=kmin, kmax=kmax)
transform = fwttools.fwt(signal=signal)
synthesized = fwttools.ifwt(wavelet_coefficients=transform)

end_time = time.time()
execution_time = end_time - start_time

left, right = parseval_identity(signal, transform)
error = relative_rmse_error(signal, synthesized) * 100

print(f"Равенство Парсеваля: {left} = {right}")
print(f"Время выполнения: {execution_time:.6f} секунд")

fig, ax = plt.subplots(figsize=(12, 6))
line1, = ax.plot(synthesized, label='Аппроксимация', color='green', linestyle='dashed', linewidth=4, marker='8')
line2, = ax.plot(signal, label='Аудиосигнал', color='black', linewidth=0, marker='o')
dummy_line = plt.Line2D([], [], color='none', label=rf'$\epsilon={error:.1f}\%$')


ax.grid(True, which="major", linestyle="-", linewidth=0.8)
ax.minorticks_on()
ax.grid(True, which="minor", linestyle=":", linewidth=0.5)

ax.legend(handles=[line1, line2, dummy_line], labelcolor="black", prop={'size': 25}, loc='upper left')
plt.title(f'Аппроксимация сигнала', fontsize=25)
plt.show()
# Out:
# Равенство Парсеваля: 4791000.0 = 4790999.999999942
# Время выполнения: 0.000000 секунд

# %% [markdown]
# ## D10

# %%
start_time = time.time()

h = daubechies_h_coeffs[10]
kmin, kmax = 0, len(h) - 1

fwttools = FwtTools(h_coeffs=h, kmin=kmin, kmax=kmax)
transform = fwttools.fwt(signal=signal)
synthesized = fwttools.ifwt(wavelet_coefficients=transform)

end_time = time.time()
execution_time = end_time - start_time

left, right = parseval_identity(signal, transform)
error = relative_rmse_error(signal, synthesized) * 100

print(f"Равенство Парсеваля: {left} = {right}")
print(f"Время выполнения: {execution_time:.6f} секунд")

fig, ax = plt.subplots(figsize=(12, 6))
line1, = ax.plot(synthesized, label='Аппроксимация', color='green', linestyle='dashed', linewidth=4, marker='8')
line2, = ax.plot(signal, label='Аудиосигнал', color='black', linewidth=0, marker='o')
dummy_line = plt.Line2D([], [], color='none', label=rf'$\epsilon={error:.1f}\%$')


ax.grid(True, which="major", linestyle="-", linewidth=0.8)
ax.minorticks_on()
ax.grid(True, which="minor", linestyle=":", linewidth=0.5)

ax.legend(handles=[line1, line2, dummy_line], labelcolor="black", prop={'size': 25}, loc='upper left')
plt.title(f'Аппроксимация сигнала', fontsize=25)
plt.show()
# Out:
# Равенство Парсеваля: 4791000.0 = 4790999.999999721
# Время выполнения: 0.001000 секунд
