# %% [markdown]
# # Преобразование сигнала при помощи коэффициентов функции Гаусса, посчитанных при помощи БПФ

# %%
# !pip install fwt-tools
# Out:
# Looking in indexes: https://test.pypi.org/simple/, https://pypi.org/simple
# Collecting fwt-tools==1.0.4
#   Downloading https://test-files.pythonhosted.org/packages/46/f0/7eb68f0c046ce394d4753d58b7ee74f37b9d64c2c60b3dbf8bf91a2fa00b/fwt_tools-1.0.4-py3-none-any.whl.metadata (758 bytes)
# Requirement already satisfied: numpy>=1.20 in c:\users\sam\miniconda3\lib\site-packages (from fwt-tools==1.0.4) (2.2.6)
# Requirement already satisfied: numba>=0.60.0 in c:\users\sam\miniconda3\lib\site-packages (from fwt-tools==1.0.4) (0.61.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\sam\miniconda3\lib\site-packages (from numba>=0.60.0->fwt-tools==1.0.4) (0.44.0)
# Downloading https://test-files.pythonhosted.org/packages/46/f0/7eb68f0c046ce394d4753d58b7ee74f37b9d64c2c60b3dbf8bf91a2fa00b/fwt_tools-1.0.4-py3-none-any.whl (9.9 kB)
# Installing collected packages: fwt-tools
#   Attempting uninstall: fwt-tools
#     Found existing installation: fwt-tools 1.0.3
#     Uninstalling fwt-tools-1.0.3:
#       Successfully uninstalled fwt-tools-1.0.3
# Successfully installed fwt-tools-1.0.4

# %%
import time

import matplotlib.pyplot as plt
from fwttools.fwt_tools import FwtTools
from fwttools.utils.error import *
from fwttools.utils.scaling_functions import build_lorentzian

from common import signal

# %% [markdown]
# ### Сигма = 1, Сдвиг = 0.25

# %%
start_time = time.time()

lorentzian = build_lorentzian(sigma=1)
fwttools = FwtTools(scaling_func=lorentzian)
transform = fwttools.fwt(signal=signal)
synthesized = fwttools.ifwt(wavelet_coefficients=transform)

end_time = time.time()
execution_time = end_time - start_time
left, right = parseval_identity(signal, transform)
error = relative_rmse_error(signal, synthesized) * 100

print(f"Равенство Парсеваля: {left} = {right}")
print(f"Время выполнения: {execution_time:.6f} секунд")

fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(fwttools.k_range, fwttools.h_coeffs, color='red', linewidth=2, marker='.')
plt.title(f'Ортонормированные коэффициенты h узловой функции', fontsize=25)
ax.grid(True, which="major", linestyle="-", linewidth=0.8)
ax.minorticks_on()
ax.grid(True, which="minor", linestyle=":", linewidth=0.5)
plt.show()
# Out:
# Равенство Парсеваля: 4791000.0 = 4791123.196071519
# Время выполнения: 0.001689 секунд

# %%
fig, ax = plt.subplots(figsize=(12, 6))
line1, = ax.plot(synthesized, label='Аппроксимация', color='green', linestyle='dashed', linewidth=4, marker='8')
line2, = ax.plot(signal, label='Аудиосигнал', color='black', linewidth=0, marker='o')
dummy_line = plt.Line2D([], [], color='none', label=rf'$\epsilon={error:.1f}\%$')

ax.grid(True, which="major", linestyle="-", linewidth=0.8)
ax.minorticks_on()
ax.grid(True, which="minor", linestyle=":", linewidth=0.5)

ax.legend(handles=[line1, line2, dummy_line], labelcolor="black", prop={'size': 25}, loc='upper left')
plt.title(f'Аппроксимация сигнала', fontsize=25)
plt.show()

# %% [markdown]
# ### Сигма = 1, Сдвиг = 0

# %%
start_time = time.time()

lorentzian = build_lorentzian(sigma=1, shift=0)
fwttools = FwtTools(scaling_func=lorentzian)
transform = fwttools.fwt(signal=signal)
synthesized = fwttools.ifwt(wavelet_coefficients=transform)

end_time = time.time()
execution_time = end_time - start_time

left, right = parseval_identity(signal, transform)
error = relative_rmse_error(signal, synthesized) * 100

print(f"Равенство Парсеваля: {left} = {right}")
print(f"Время выполнения: {execution_time:.6f} секунд")

fig, ax = plt.subplots(figsize=(12, 6))
line1, = ax.plot(synthesized, label='Аппроксимация', color='green', linestyle='dashed', linewidth=4, marker='8')
line2, = ax.plot(signal, label='Аудиосигнал', color='black', linewidth=0, marker='o')
dummy_line = plt.Line2D([], [], color='none', label=rf'$\epsilon={error:.1f}\%$')

ax.grid(True, which="major", linestyle="-", linewidth=0.8)
ax.minorticks_on()
ax.grid(True, which="minor", linestyle=":", linewidth=0.5)
ax.legend(handles=[line1, line2, dummy_line], labelcolor="black", prop={'size': 25}, loc='upper left')
plt.title(f'Аппроксимация сигнала', fontsize=25)
plt.show()
# Out:
# Равенство Парсеваля: 4791000.0 = 4604184.280572596
# Время выполнения: 0.001000 секунд

# %% [markdown]
# ### Сигма = 1, Сдвиг = 5.25

# %%
start_time = time.time()

lorentzian = build_lorentzian(sigma=1, shift=5.25)
fwttools = FwtTools(scaling_func=lorentzian)
transform = fwttools.fwt(signal=signal)
synthesized = fwttools.ifwt(wavelet_coefficients=transform)

end_time = time.time()
execution_time = end_time - start_time

left, right = parseval_identity(signal, transform)
error = relative_rmse_error(signal, synthesized) * 100

print(f"Равенство Парсеваля: {left} = {right}")
print(f"Время выполнения: {execution_time:.6f} секунд")

fig, ax = plt.subplots(figsize=(12, 6))
line1, = ax.plot(synthesized, label='Аппроксимация', color='green', linestyle='dashed', linewidth=4, marker='8')
line2, = ax.plot(signal, label='Аудиосигнал', color='black', linewidth=0, marker='o')
dummy_line = plt.Line2D([], [], color='none', label=rf'$\epsilon={error:.1f}\%$')

ax.grid(True, which="major", linestyle="-", linewidth=0.8)
ax.minorticks_on()
ax.grid(True, which="minor", linestyle=":", linewidth=0.5)
ax.legend(handles=[line1, line2, dummy_line], labelcolor="black", prop={'size': 25}, loc='upper left')
plt.title(f'Аппроксимация сигнала', fontsize=25)
plt.show()
# Out:
# Равенство Парсеваля: 4791000.0 = 4791121.235420013
# Время выполнения: 0.000000 секунд

# %% [markdown]
# ### Сигма = 2, Сдвиг = 0.25

# %%
start_time = time.time()

lorentzian = build_lorentzian(sigma=2)
fwttools = FwtTools(scaling_func=lorentzian)
transform = fwttools.fwt(signal=signal)
synthesized = fwttools.ifwt(wavelet_coefficients=transform)

end_time = time.time()
execution_time = end_time - start_time

left, right = parseval_identity(signal, transform)
error = relative_rmse_error(signal, synthesized) * 100

print(f"Равенство Парсеваля: {left} = {right}")
print(f"Время выполнения: {execution_time:.6f} секунд")

fig, ax = plt.subplots(figsize=(12, 6))
line1, = ax.plot(synthesized, label='Аппроксимация', color='green', linestyle='dashed', linewidth=4, marker='8')
line2, = ax.plot(signal, label='Аудиосигнал', color='black', linewidth=0, marker='o')
dummy_line = plt.Line2D([], [], color='none', label=rf'$\epsilon={error:.1f}\%$')


ax.grid(True, which="major", linestyle="-", linewidth=0.8)
ax.minorticks_on()
ax.grid(True, which="minor", linestyle=":", linewidth=0.5)

ax.legend(handles=[line1, line2, dummy_line], labelcolor="black", prop={'size': 25}, loc='upper left')
plt.title(f'Аппроксимация сигнала', fontsize=25)
plt.show()
# Out:
# Равенство Парсеваля: 4791000.0 = 4791479.3110913765
# Время выполнения: 0.000000 секунд

# %% [markdown]
# ### Сигма = 3, Сдвиг = 0.25

# %%
start_time = time.time()

lorentzian = build_lorentzian(sigma=3)
fwttools = FwtTools(scaling_func=lorentzian)
transform = fwttools.fwt(signal=signal)
synthesized = fwttools.ifwt(wavelet_coefficients=transform)

end_time = time.time()
execution_time = end_time - start_time

left, right = parseval_identity(signal, transform)
error = relative_rmse_error(signal, synthesized) * 100

print(f"Равенство Парсеваля: {left} = {right}")
print(f"Время выполнения: {execution_time:.6f} секунд")

fig, ax = plt.subplots(figsize=(12, 6))
line1, = ax.plot(synthesized, label='Аппроксимация', color='green', linestyle='dashed', linewidth=4, marker='8')
line2, = ax.plot(signal, label='Аудиосигнал', color='black', linewidth=0, marker='o')
dummy_line = plt.Line2D([], [], color='none', label=rf'$\epsilon={error:.1f}\%$')


ax.grid(True, which="major", linestyle="-", linewidth=0.8)
ax.minorticks_on()
ax.grid(True, which="minor", linestyle=":", linewidth=0.5)

ax.legend(handles=[line1, line2, dummy_line], labelcolor="black", prop={'size': 25}, loc='upper left')
plt.title(f'Аппроксимация сигнала', fontsize=25)
plt.show()
# Out:
# Равенство Парсеваля: 4791000.0 = 4796280.340290169
# Время выполнения: 0.001000 секунд

# %% [markdown]
# ### Сигма = 0.1, Сдвиг = 0.25

# %%
start_time = time.time()

lorentzian = build_lorentzian(sigma=0.1)
fwttools = FwtTools(kmin=-10, kmax=10, scaling_func=lorentzian)
transform = fwttools.fwt(signal=signal)
synthesized = fwttools.ifwt(wavelet_coefficients=transform)

end_time = time.time()
execution_time = end_time - start_time

left, right = parseval_identity(signal, transform)
error = relative_rmse_error(signal, synthesized) * 100

print(f"Равенство Парсеваля: {left} = {right}")
print(f"Время выполнения: {execution_time:.6f} секунд")

fig, ax = plt.subplots(figsize=(12, 6))
line1, = ax.plot(synthesized, label='Аппроксимация', color='green', linestyle='dashed', linewidth=4, marker='8')
line2, = ax.plot(signal, label='Аудиосигнал', color='black', linewidth=0, marker='o')
dummy_line = plt.Line2D([], [], color='none', label=rf'$\epsilon={error:.1f}\%$')


ax.grid(True, which="major", linestyle="-", linewidth=0.8)
ax.minorticks_on()
ax.grid(True, which="minor", linestyle=":", linewidth=0.5)

ax.legend(handles=[line1, line2, dummy_line], labelcolor="black", prop={'size': 25}, loc='upper left')
plt.title(f'Аппроксимация сигнала', fontsize=25)
plt.show()
# Out:
# Равенство Парсеваля: 4791000.0 = 4795156.5946859475
# Время выполнения: 0.001004 секунд
